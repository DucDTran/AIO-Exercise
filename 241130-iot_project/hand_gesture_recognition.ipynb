# %%
# !pip install -q torchmetrics
# !pip install -q safetensors
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset
import safetensors

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("hand_gestures.yaml")
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.6),
            nn.Linear(128, len(list_label)),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob,dim=1)
        return torch.where(softmax_prob[0,chosen_ind]>threshold,chosen_ind,-1)

    def predict_with_known_class(self,x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob,dim=1)

    def score(self,logits):
        return -torch.amax(logits,dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(False,max_num_hands=1,min_detection_confidence=0.5)

    def detectHand(self,frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x,y,z = landmark.x,landmark.y,landmark.z
                    hand.extend([x,y,z])
            hands.append(hand)
        return hands,annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime('%d-%m %H:%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number,data in enumerate(trainloader):
            inputs,labels = data
            optimizer.zero_grad()
            preds = model(inputs)
            loss = loss_function(preds,labels)
            loss.backward()
            optimizer.step()
            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)
        if early_stopper.early_stop(avg_vloss):
            print(f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}")
            break

    model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="./data/"
LIST_LABEL = label_dict_from_config_file("hand_gestures.yaml")
train_path = os.path.join(DATA_FOLDER_PATH,"landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH,"landmark_val.csv")
save_path = './models'
os.makedirs(save_path,exist_ok=True)

trainset = CustomImageDataset(train_path)
trainloader = torch.utils.data.DataLoader(trainset,batch_size=40,shuffle=True)

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset,batch_size=50, shuffle=False)

model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30,min_delta=0.01)
optimizer = optim.Adam(model.parameters(),lr=0.0001)

model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.19823355972766876, val:0.23549488186836243
# LOSS train 1.6112645818636968 valid 1.6004545092582703
# Training vs. Validation Loss {'Training': 1.6112645818636968, 'Validation': 1.6004545092582703} 1
# Training vs. Validation accuracy {'Training': 0.19823355972766876, 'Validation': 0.23549488186836243} 1
# Epoch 1:
# Accuracy train:0.23748773336410522, val:0.3890784978866577
# LOSS train 1.5903233748215895 valid 1.5815273920694988
# Training vs. Validation Loss {'Training': 1.5903233748215895, 'Validation': 1.5815273920694988} 2
# Training vs. Validation accuracy {'Training': 0.23748773336410522, 'Validation': 0.3890784978866577} 2
# Epoch 2:
# Accuracy train:0.35721296072006226, val:0.48122867941856384
# LOSS train 1.5703138158871577 valid 1.5603810946146648
# Training vs. Validation Loss {'Training': 1.5703138158871577, 'Validation': 1.5603810946146648} 3
# Training vs. Validation accuracy {'Training': 0.35721296072006226, 'Validation': 0.48122867941856384} 3
# Epoch 3:
# Accuracy train:0.42492640018463135, val:0.4266211688518524
# LOSS train 1.5440288461171663 valid 1.5291110674540203
# Training vs. Validation Loss {'Training': 1.5440288461171663, 'Validation': 1.5291110674540203} 4
# Training vs. Validation accuracy {'Training': 0.42492640018463135, 'Validation': 0.4266211688518524} 4
# Epoch 4:
# Accuracy train:0.4543670117855072, val:0.46075084805488586
# LOSS train 1.4996701937455397 valid 1.4687353372573853
# Training vs. Validation Loss {'Training': 1.4996701937455397, 'Validation': 1.4687353372573853} 5
# Training vs. Validation accuracy {'Training': 0.4543670117855072, 'Validation': 0.46075084805488586} 5
# Epoch 5:
# Accuracy train:0.5220804810523987, val:0.43344709277153015
# LOSS train 1.42568989441945 valid 1.3780971666177113
# Training vs. Validation Loss {'Training': 1.42568989441945, 'Validation': 1.3780971666177113} 6
# Training vs. Validation accuracy {'Training': 0.5220804810523987, 'Validation': 0.43344709277153015} 6
# Epoch 6:
# Accuracy train:0.5593719482421875, val:0.457337886095047
# LOSS train 1.3160272057239826 valid 1.2859557072321575
# Training vs. Validation Loss {'Training': 1.3160272057239826, 'Validation': 1.2859557072321575} 7
# Training vs. Validation accuracy {'Training': 0.5593719482421875, 'Validation': 0.457337886095047} 7
# Epoch 7:
# Accuracy train:0.5770363211631775, val:0.49146756529808044
# LOSS train 1.2013786045404582 valid 1.1380504220724106
# Training vs. Validation Loss {'Training': 1.2013786045404582, 'Validation': 1.1380504220724106} 8
# Training vs. Validation accuracy {'Training': 0.5770363211631775, 'Validation': 0.49146756529808044} 8
# Epoch 8:
# Accuracy train:0.6054955720901489, val:0.5836177468299866
# LOSS train 1.0586408995665038 valid 1.031554768482844
# Training vs. Validation Loss {'Training': 1.0586408995665038, 'Validation': 1.031554768482844} 9
# Training vs. Validation accuracy {'Training': 0.6054955720901489, 'Validation': 0.5836177468299866} 9
# Epoch 9:
# Accuracy train:0.6398429870605469, val:0.6757678985595703
# LOSS train 0.9444876061036036 valid 0.8785411727925142
# Training vs. Validation Loss {'Training': 0.9444876061036036, 'Validation': 0.8785411727925142} 10
# Training vs. Validation accuracy {'Training': 0.6398429870605469, 'Validation': 0.6757678985595703} 10
# Epoch 10:
# Accuracy train:0.7330716252326965, val:0.6928327679634094
# LOSS train 0.8235746232362894 valid 0.7592848744243383
# Training vs. Validation Loss {'Training': 0.8235746232362894, 'Validation': 0.7592848744243383} 11
# Training vs. Validation accuracy {'Training': 0.7330716252326965, 'Validation': 0.6928327679634094} 11
# Epoch 11:
# Accuracy train:0.7831206917762756, val:0.7064846158027649
# LOSS train 0.7044018701865122 valid 0.6466433679064115
# Training vs. Validation Loss {'Training': 0.7044018701865122, 'Validation': 0.6466433679064115} 12
# Training vs. Validation accuracy {'Training': 0.7831206917762756, 'Validation': 0.7064846158027649} 12
# Epoch 12:
# Accuracy train:0.8312070369720459, val:0.80887371301651
# LOSS train 0.5887621102424768 valid 0.5164467397456368
# Training vs. Validation Loss {'Training': 0.5887621102424768, 'Validation': 0.5164467397456368} 13
# Training vs. Validation accuracy {'Training': 0.8312070369720459, 'Validation': 0.80887371301651} 13
# Epoch 13:
# Accuracy train:0.8753679990768433, val:0.8395904302597046
# LOSS train 0.47039929261574376 valid 0.4309494250143568
# Training vs. Validation Loss {'Training': 0.47039929261574376, 'Validation': 0.4309494250143568} 14
# Training vs. Validation accuracy {'Training': 0.8753679990768433, 'Validation': 0.8395904302597046} 14
# Epoch 14:
# Accuracy train:0.8557409048080444, val:0.9624573588371277
# LOSS train 0.4043278814508365 valid 0.33331097786625224
# Training vs. Validation Loss {'Training': 0.4043278814508365, 'Validation': 0.33331097786625224} 15
# Training vs. Validation accuracy {'Training': 0.8557409048080444, 'Validation': 0.9624573588371277} 15
# Epoch 15:
# Accuracy train:0.9195289611816406, val:0.9692832827568054
# LOSS train 0.33624360996943253 valid 0.2611084886205693
# Training vs. Validation Loss {'Training': 0.33624360996943253, 'Validation': 0.2611084886205693} 16
# Training vs. Validation accuracy {'Training': 0.9195289611816406, 'Validation': 0.9692832827568054} 16
# Epoch 16:
# Accuracy train:0.9499509334564209, val:0.9761092066764832
# LOSS train 0.2768729804800107 valid 0.18921176033715406
# Training vs. Validation Loss {'Training': 0.2768729804800107, 'Validation': 0.18921176033715406} 17
# Training vs. Validation accuracy {'Training': 0.9499509334564209, 'Validation': 0.9761092066764832} 17
# Epoch 17:
# Accuracy train:0.9548577070236206, val:0.9761092066764832
# LOSS train 0.2313176513864444 valid 0.13611025696930787
# Training vs. Validation Loss {'Training': 0.2313176513864444, 'Validation': 0.13611025696930787} 18
# Training vs. Validation accuracy {'Training': 0.9548577070236206, 'Validation': 0.9761092066764832} 18
# Epoch 18:
# Accuracy train:0.9528949856758118, val:0.979522168636322
# LOSS train 0.21646225910920364 valid 0.10496686880166332
# Training vs. Validation Loss {'Training': 0.21646225910920364, 'Validation': 0.10496686880166332} 19
# Training vs. Validation accuracy {'Training': 0.9528949856758118, 'Validation': 0.979522168636322} 19
# Epoch 19:
# Accuracy train:0.9685966372489929, val:0.9829351305961609
# LOSS train 0.17352407081769064 valid 0.0701047849142924
# Training vs. Validation Loss {'Training': 0.17352407081769064, 'Validation': 0.0701047849142924} 20
# Training vs. Validation accuracy {'Training': 0.9685966372489929, 'Validation': 0.9829351305961609} 20
# Epoch 20:
# Accuracy train:0.9784101843833923, val:0.9863481521606445
# LOSS train 0.14927862871151704 valid 0.04847090792221328
# Training vs. Validation Loss {'Training': 0.14927862871151704, 'Validation': 0.04847090792221328} 21
# Training vs. Validation accuracy {'Training': 0.9784101843833923, 'Validation': 0.9863481521606445} 21
# Epoch 21:
# Accuracy train:0.9764475226402283, val:0.979522168636322
# LOSS train 0.14702506506672272 valid 0.04184095844781647
# Training vs. Validation Loss {'Training': 0.14702506506672272, 'Validation': 0.04184095844781647} 22
# Training vs. Validation accuracy {'Training': 0.9764475226402283, 'Validation': 0.979522168636322} 22
# Epoch 22:
# Accuracy train:0.9774288535118103, val:0.979522168636322
# LOSS train 0.10327402831843266 valid 0.04476870260744666
# Training vs. Validation Loss {'Training': 0.10327402831843266, 'Validation': 0.04476870260744666} 23
# Training vs. Validation accuracy {'Training': 0.9774288535118103, 'Validation': 0.979522168636322} 23
# Epoch 23:
# Accuracy train:0.98233562707901, val:0.9965870380401611
# LOSS train 0.10128042388420838 valid 0.023320770196733065
# Training vs. Validation Loss {'Training': 0.10128042388420838, 'Validation': 0.023320770196733065} 24
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9965870380401611} 24
# Epoch 24:
# Accuracy train:0.9803729057312012, val:0.979522168636322
# LOSS train 0.09273757986151256 valid 0.03450500262745967
# Training vs. Validation Loss {'Training': 0.09273757986151256, 'Validation': 0.03450500262745967} 25
# Training vs. Validation accuracy {'Training': 0.9803729057312012, 'Validation': 0.979522168636322} 25
# Epoch 25:
# Accuracy train:0.9872424006462097, val:0.9726962447166443
# LOSS train 0.09806187343425475 valid 0.044056899952314175
# Training vs. Validation Loss {'Training': 0.09806187343425475, 'Validation': 0.044056899952314175} 26
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9726962447166443} 26
# Epoch 26:
# Accuracy train:0.98233562707901, val:0.9829351305961609
# LOSS train 0.09467682679398702 valid 0.033688563053146936
# Training vs. Validation Loss {'Training': 0.09467682679398702, 'Validation': 0.033688563053146936} 27
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9829351305961609} 27
# Epoch 27:
# Accuracy train:0.9862610697746277, val:0.9829351305961609
# LOSS train 0.07358727038193208 valid 0.02744563879969064
# Training vs. Validation Loss {'Training': 0.07358727038193208, 'Validation': 0.02744563879969064} 28
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9829351305961609} 28
# Epoch 28:
# Accuracy train:0.9744848012924194, val:0.9829351305961609
# LOSS train 0.08726146938995673 valid 0.02897426905595542
# Training vs. Validation Loss {'Training': 0.08726146938995673, 'Validation': 0.02897426905595542} 29
# Training vs. Validation accuracy {'Training': 0.9744848012924194, 'Validation': 0.9829351305961609} 29
# Epoch 29:
# Accuracy train:0.9803729057312012, val:0.9829351305961609
# LOSS train 0.08512656132762249 valid 0.041166215223105006
# Training vs. Validation Loss {'Training': 0.08512656132762249, 'Validation': 0.041166215223105006} 30
# Training vs. Validation accuracy {'Training': 0.9803729057312012, 'Validation': 0.9829351305961609} 30
# Epoch 30:
# Accuracy train:0.9882237315177917, val:0.9829351305961609
# LOSS train 0.0786555282270106 valid 0.020174491156164247
# Training vs. Validation Loss {'Training': 0.0786555282270106, 'Validation': 0.020174491156164247} 31
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9829351305961609} 31
# Epoch 31:
# Accuracy train:0.9901864528656006, val:0.9829351305961609
# LOSS train 0.06284481960420425 valid 0.025207576453491736
# Training vs. Validation Loss {'Training': 0.06284481960420425, 'Validation': 0.025207576453491736} 32
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9829351305961609} 32
# Epoch 32:
# Accuracy train:0.9852796792984009, val:0.9897611141204834
# LOSS train 0.0692109685176267 valid 0.013569379940842433
# Training vs. Validation Loss {'Training': 0.0692109685176267, 'Validation': 0.013569379940842433} 33
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9897611141204834} 33
# Epoch 33:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.07011330330099624 valid 0.013832266186606526
# Training vs. Validation Loss {'Training': 0.07011330330099624, 'Validation': 0.013832266186606526} 34
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 34
# Epoch 34:
# Accuracy train:0.9901864528656006, val:0.9829351305961609
# LOSS train 0.051764071166801914 valid 0.02187086933554383
# Training vs. Validation Loss {'Training': 0.051764071166801914, 'Validation': 0.02187086933554383} 35
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9829351305961609} 35
# Epoch 35:
# Accuracy train:0.9901864528656006, val:0.9863481521606445
# LOSS train 0.050016275678689666 valid 0.016595837278146064
# Training vs. Validation Loss {'Training': 0.050016275678689666, 'Validation': 0.016595837278146064} 36
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9863481521606445} 36
# Epoch 36:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.051234438495997056 valid 0.012537339403934311
# Training vs. Validation Loss {'Training': 0.051234438495997056, 'Validation': 0.012537339403934311} 37
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 37
# Epoch 37:
# Accuracy train:0.9882237315177917, val:0.9863481521606445
# LOSS train 0.057308081859866015 valid 0.021068261818678973
# Training vs. Validation Loss {'Training': 0.057308081859866015, 'Validation': 0.021068261818678973} 38
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9863481521606445} 38
# Epoch 38:
# Accuracy train:0.9862610697746277, val:0.9965870380401611
# LOSS train 0.050881550718958564 valid 0.01363772441194063
# Training vs. Validation Loss {'Training': 0.050881550718958564, 'Validation': 0.01363772441194063} 39
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9965870380401611} 39
# Epoch 39:
# Accuracy train:0.9882237315177917, val:0.9965870380401611
# LOSS train 0.04723105608270718 valid 0.010997297195596426
# Training vs. Validation Loss {'Training': 0.04723105608270718, 'Validation': 0.010997297195596426} 40
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9965870380401611} 40
# Epoch 40:
# Accuracy train:0.9892051219940186, val:1.0
# LOSS train 0.04739344145099704 valid 0.007950713533621942
# Training vs. Validation Loss {'Training': 0.04739344145099704, 'Validation': 0.007950713533621942} 41
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 1.0} 41
# Epoch 41:
# Accuracy train:0.9911677837371826, val:1.0
# LOSS train 0.05262650796570457 valid 0.008051604048281055
# Training vs. Validation Loss {'Training': 0.05262650796570457, 'Validation': 0.008051604048281055} 42
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 1.0} 42
# Epoch 42:
# Accuracy train:0.9872424006462097, val:1.0
# LOSS train 0.03771012382975851 valid 0.005545281926970347
# Training vs. Validation Loss {'Training': 0.03771012382975851, 'Validation': 0.005545281926970347} 43
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 1.0} 43
# Epoch 43:
# Accuracy train:0.9852796792984009, val:1.0
# LOSS train 0.0461371924656515 valid 0.006158949043917043
# Training vs. Validation Loss {'Training': 0.0461371924656515, 'Validation': 0.006158949043917043} 44
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 1.0} 44
# Epoch 44:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.04001929215155542 valid 0.0069383177724375855
# Training vs. Validation Loss {'Training': 0.04001929215155542, 'Validation': 0.0069383177724375855} 45
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 45
# Epoch 45:
# Accuracy train:0.9911677837371826, val:1.0
# LOSS train 0.04028119429802665 valid 0.008149919200604927
# Training vs. Validation Loss {'Training': 0.04028119429802665, 'Validation': 0.008149919200604927} 46
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 1.0} 46
# Epoch 46:
# Accuracy train:0.9911677837371826, val:1.0
# LOSS train 0.028837184672458813 valid 0.005803297523925721
# Training vs. Validation Loss {'Training': 0.028837184672458813, 'Validation': 0.005803297523925721} 47
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 1.0} 47
# Epoch 47:
# Accuracy train:0.9901864528656006, val:0.9897611141204834
# LOSS train 0.03139669957678192 valid 0.016439612391422997
# Training vs. Validation Loss {'Training': 0.03139669957678192, 'Validation': 0.016439612391422997} 48
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9897611141204834} 48
# Epoch 48:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.05050060796873787 valid 0.012238325045473175
# Training vs. Validation Loss {'Training': 0.05050060796873787, 'Validation': 0.012238325045473175} 49
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 49
# Epoch 49:
# Accuracy train:0.9852796792984009, val:1.0
# LOSS train 0.0419481117099237 valid 0.0030594352838306804
# Training vs. Validation Loss {'Training': 0.0419481117099237, 'Validation': 0.0030594352838306804} 50
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 1.0} 50
# Epoch 50:
# Accuracy train:0.9882237315177917, val:1.0
# LOSS train 0.04000135797720689 valid 0.006793725996279439
# Training vs. Validation Loss {'Training': 0.04000135797720689, 'Validation': 0.006793725996279439} 51
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 1.0} 51
# Epoch 51:
# Accuracy train:0.9892051219940186, val:1.0
# LOSS train 0.05020261179799071 valid 0.0081076029612935
# Training vs. Validation Loss {'Training': 0.05020261179799071, 'Validation': 0.0081076029612935} 52
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 1.0} 52
# Epoch 52:
# Accuracy train:0.9862610697746277, val:1.0
# LOSS train 0.03122642899576861 valid 0.00870070622795538
# Training vs. Validation Loss {'Training': 0.03122642899576861, 'Validation': 0.00870070622795538} 53
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 1.0} 53
# Epoch 53:
# Accuracy train:0.9911677837371826, val:1.0
# LOSS train 0.03761577016960543 valid 0.005916559266855377
# Training vs. Validation Loss {'Training': 0.03761577016960543, 'Validation': 0.005916559266855377} 54
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 1.0} 54
# Epoch 54:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.04528099556381886 valid 0.01376268286336805
# Training vs. Validation Loss {'Training': 0.04528099556381886, 'Validation': 0.01376268286336805} 55
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 55
# Epoch 55:
# Accuracy train:0.9921491742134094, val:1.0
# LOSS train 0.03537677416506295 valid 0.007391474740567598
# Training vs. Validation Loss {'Training': 0.03537677416506295, 'Validation': 0.007391474740567598} 56
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 1.0} 56
# Epoch 56:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.031112458198689498 valid 0.016373901026933407
# Training vs. Validation Loss {'Training': 0.031112458198689498, 'Validation': 0.016373901026933407} 57
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 57
# Epoch 57:
# Accuracy train:0.9911677837371826, val:1.0
# LOSS train 0.034705337387724564 valid 0.007631297920928167
# Training vs. Validation Loss {'Training': 0.034705337387724564, 'Validation': 0.007631297920928167} 58
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 1.0} 58
# Epoch 58:
# Accuracy train:0.9911677837371826, val:1.0
# LOSS train 0.03599628158218156 valid 0.008532515810202312
# Training vs. Validation Loss {'Training': 0.03599628158218156, 'Validation': 0.008532515810202312} 59
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 1.0} 59
# Epoch 59:
# Accuracy train:0.9901864528656006, val:1.0
# LOSS train 0.03133221005555242 valid 0.004648303009162191
# Training vs. Validation Loss {'Training': 0.03133221005555242, 'Validation': 0.004648303009162191} 60
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 1.0} 60
# Epoch 60:
# Accuracy train:0.9901864528656006, val:0.9863481521606445
# LOSS train 0.03837630906715416 valid 0.023569491534544795
# Training vs. Validation Loss {'Training': 0.03837630906715416, 'Validation': 0.023569491534544795} 61
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 1.0} 79
# Epoch 79:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.03045623262788957 valid 0.008862767820725518
# Training vs. Validation Loss {'Training': 0.03045623262788957, 'Validation': 0.008862767820725518} 80
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 80
# Epoch 80:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.041406602795737296 valid 0.007830600443185176
# Training vs. Validation Loss {'Training': 0.041406602795737296, 'Validation': 0.007830600443185176} 81
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 81
# Epoch 81:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.026938514927258857 valid 0.014540545401208268
# Training vs. Validation Loss {'Training': 0.026938514927258857, 'Validation': 0.014540545401208268} 82
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 82
# Epoch 82:
# Accuracy train:0.9901864528656006, val:1.0
# LOSS train 0.023289180548789982 valid 0.009505319105680124
# Training vs. Validation Loss {'Training': 0.023289180548789982, 'Validation': 0.009505319105680124} 83
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 1.0} 83
# Epoch 83:
# Accuracy train:0.9911677837371826, val:0.9897611141204834
# LOSS train 0.024009613203816116 valid 0.018864549848027917
# Training vs. Validation Loss {'Training': 0.024009613203816116, 'Validation': 0.018864549848027917} 84
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9897611141204834} 84
# Epoch 84:
# Accuracy train:0.9931305050849915, val:0.9829351305961609
# LOSS train 0.019415346041429214 valid 0.025977433757664887
# Training vs. Validation Loss {'Training': 0.019415346041429214, 'Validation': 0.025977433757664887} 85
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9829351305961609} 85
# Epoch 85:
# Accuracy train:0.9950932264328003, val:1.0
# LOSS train 0.024292376546117548 valid 0.010021832089440371
# Training vs. Validation Loss {'Training': 0.024292376546117548, 'Validation': 0.010021832089440371} 86
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 1.0} 86
# Epoch 86:
# Accuracy train:0.9931305050849915, val:0.9863481521606445
# LOSS train 0.02625835147829583 valid 0.0324395501785375
# Training vs. Validation Loss {'Training': 0.02625835147829583, 'Validation': 0.0324395501785375} 87
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9863481521606445} 87
# Epoch 87:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.026597065783929653 valid 0.01204157451293971
# Training vs. Validation Loss {'Training': 0.026597065783929653, 'Validation': 0.01204157451293971} 88
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 88
# Epoch 88:
# Accuracy train:0.9921491742134094, val:1.0
# LOSS train 0.023658242542296648 valid 0.009981311155153586
# Training vs. Validation Loss {'Training': 0.023658242542296648, 'Validation': 0.009981311155153586} 89
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 1.0} 89
# Epoch 89:
# Accuracy train:0.9941118955612183, val:1.0
# LOSS train 0.026095969271129713 valid 0.01254379298643471
# Training vs. Validation Loss {'Training': 0.026095969271129713, 'Validation': 0.01254379298643471} 90
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 1.0} 90
# Epoch 90:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.026064494300114278 valid 0.009493361806183506
# Training vs. Validation Loss {'Training': 0.026064494300114278, 'Validation': 0.009493361806183506} 91
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 91
# Epoch 91:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.023701262284213535 valid 0.008265799383025296
# Training vs. Validation Loss {'Training': 0.023701262284213535, 'Validation': 0.008265799383025296} 92
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 92
# Epoch 92:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.020277606401717864 valid 0.008970495628659592
# Training vs. Validation Loss {'Training': 0.020277606401717864, 'Validation': 0.008970495628659592} 93
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 93
# Epoch 93:
# Accuracy train:0.9931305050849915, val:1.0
# LOSS train 0.02488542752018055 valid 0.00833304190553008
# Training vs. Validation Loss {'Training': 0.02488542752018055, 'Validation': 0.00833304190553008} 94
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 1.0} 94
# Epoch 94:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.023453295454741098 valid 0.010520018037709633
# Training vs. Validation Loss {'Training': 0.023453295454741098, 'Validation': 0.010520018037709633} 95
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 95
# Epoch 95:
# Accuracy train:0.9960745573043823, val:1.0
# LOSS train 0.02540195053622413 valid 0.008269322416310843
# Training vs. Validation Loss {'Training': 0.02540195053622413, 'Validation': 0.008269322416310843} 96
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation':
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 115
# Epoch 115:
# Accuracy train:0.9980372786521912, val:0.9897611141204834
# LOSS train 0.011596553994772526 valid 0.0191079898356179
# Training vs. Validation Loss {'Training': 0.011596553994772526, 'Validation': 0.0191079898356179} 116
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9897611141204834} 116
# Epoch 116:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.013511591243933743 valid 0.014853384928836514
# Training vs. Validation Loss {'Training': 0.013511591243933743, 'Validation': 0.014853384928836514} 117
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 117
# Epoch 117:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.021856775630462486 valid 0.010051559660865905
# Training vs. Validation Loss {'Training': 0.021856775630462486, 'Validation': 0.010051559660865905} 118
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 118
# Epoch 118:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.015256797975430695 valid 0.0174669859566355
# Training vs. Validation Loss {'Training': 0.015256797975430695, 'Validation': 0.0174669859566355} 119
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 119
# Epoch 119:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.016990812967728395 valid 0.011204157682281371
# Training vs. Validation Loss {'Training': 0.016990812967728395, 'Validation': 0.011204157682281371} 120
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 120
# Epoch 120:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.014860535752422247 valid 0.017154520630962605
# Training vs. Validation Loss {'Training': 0.014860535752422247, 'Validation': 0.017154520630962605} 121
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 121
# Epoch 121:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.012813451572303446 valid 0.014747600432788962
# Training vs. Validation Loss {'Training': 0.012813451572303446, 'Validation': 0.014747600432788962} 122
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 122
# Epoch 122:
# Accuracy train:0.9980372786521912, val:0.9965870380401611
# LOSS train 0.00902079479027844 valid 0.011116317950722987
# Training vs. Validation Loss {'Training': 0.00902079479027844, 'Validation': 0.011116317950722987} 123
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9965870380401611} 123
# Epoch 123:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.013651252930195859 valid 0.010110836158370754
# Training vs. Validation Loss {'Training': 0.013651252930195859, 'Validation': 0.010110836158370754} 124
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 124
# Epoch 124:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.014544007435548477 valid 0.014411745353669403
# Training vs. Validation Loss {'Training': 0.014544007435548477, 'Validation': 0.014411745353669403} 125
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 125
# Epoch 125:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.012358424860464696 valid 0.013553417432945025
# Training vs. Validation Loss {'Training': 0.012358424860464696, 'Validation': 0.013553417432945025} 126
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 126
# Epoch 126:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.01192646302605191 valid 0.016775594522120702
# Training vs. Validation Loss {'Training': 0.01192646302605191, 'Validation': 0.016775594522120702} 127
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 127
# Epoch 127:
# Accuracy train:0.9980372786521912, val:0.9897611141204834
# LOSS train 0.015665302890388724 valid 0.02793731535683719
# Training vs. Validation Loss {'Training': 0.015665302890388724, 'Validation': 0.02793731535683719} 128
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9897611141204834} 128
# Epoch 128:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.019054322122918584 valid 0.012809979480455999
# Training vs. Validation Loss {'Training': 0.019054322122918584, 'Validation': 0.012809979480455999} 129
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 129
# Epoch 129:
# Accuracy train:0.999018669128418, val:0.9931740760803223
# LOSS train 0.0069985937600274785 valid 0.019274722472478818
# Training vs. Validation Loss {'Training': 0.0069985937600274785, 'Validation': 0.019274722472478818} 130
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9931740760803223} 130
# stopping at epoch 129, minimum: 0.0030594352838306804
# tensor(0.9932)

# %%
list_label = label_dict_from_config_file("hand_gestures.yaml")
DATA_FOLDER_PATH="./data/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))
test_loader = torch.utils.data.DataLoader(testset,batch_size=20,shuffle=False)

network = NeuralNetwork()
network.load_state_dict(safetensors.torch.load_model(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    preds = network(test_input)
    acc_test.update(preds, test_label)
print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.9724409580230713
# ========================================================================
